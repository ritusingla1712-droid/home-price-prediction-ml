# %% [markdown]
# ## Home Price Prediction

# %% [markdown]
# ## Project Description:
#
# In this particular project, we are using a dataset that contains information like, Address, Rooms, Type, Price, Seller etc and using that to predict the price of a given house.
# However, before you go ahead and make a prediction, it is advised that you first pre-process the data, since it may contain some irregularities and noise. In addition, try various tricks and techniques in order to gain the best accuracy in your predictions.

# %% [markdown]
# ## Objective
# To build a machine learning model that predicts house prices based on key features and helps understand factors influencing property valuation.

# %% [markdown]
# ## Data Loading
# In this step, the dataset is loaded into the environment for further analysis.
# The dataset contains information about different properties, including their features and corresponding prices.

# %%
# Import required libraries for data analysis and machine learning
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset
data = pd.read_csv(r"C:\Users\ritus\Downloads\ML Linear Regression Home Price Prediction & Analysis Project  Resource16932049360 (1).txt")

# Display the data 
data
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis  03/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %% [markdown]
# ## Data Understanding
# Before performing any analysis, it is important to understand the structure and characteristics of the dataset. This includes checking the number of rows and columns, data types, and summary statistics of numerical features.
# This step helps in identifying potential issues such as missing values, incorrect data types, and outliers.

# %%
data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         34857 non-null  object
#  1   Address        34857 non-null  object
#  2   Rooms          34857 non-null  int64
#  3   Type           34857 non-null  object
#  4   Price          27247 non-null  float64
#  5   Method         34857 non-null  object
#  6   SellerG        34857 non-null  object
#  7   Date           34857 non-null  object
#  8   Distance       34856 non-null  float64
#  9   Postcode       34856 non-null  float64
#  10  Bedroom2       26640 non-null  float64
#  11  Bathroom       26631 non-null  float64
#  12  Car            26129 non-null  float64
#  13  Landsize       23047 non-null  float64
#  14  BuildingArea   13742 non-null  float64
#  15  YearBuilt      15551 non-null  float64
#  16  CouncilArea    34854 non-null  object
# ...

# %%
data.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# ...

# %% [markdown]
# ## Data Cleaning
# Data cleaning is a crucial step to ensure the dataset is accurate and suitable for analysis and modeling. In this step:
#
# - Missing values are identified and handled appropriately
# - Duplicate records are removed
# - Inconsistent or incorrect data entries are corrected
#
# Proper data cleaning improves the quality of the dataset and enhances model performance.

# %%
# Drop the columns that are not required for the analysis or not affect your targeted column 
data.drop(["Address", "Date", "Postcode", "YearBuilt", "Lattitude", "Longtitude"],axis = 1, inplace = True)

# %%
data
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# ...

# %%
# Check missing values
data.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Distance             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# CouncilArea          3
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
data.columns
# Out:
# Index(['Suburb', 'Rooms', 'Type', 'Price', 'Method', 'SellerG', 'Distance',
#        'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea',
#        'CouncilArea', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
# Fill missing values
data[['Distance','Bedroom2', 'Bathroom', 'Car','Propertycount']] = data[['Distance','Bedroom2', 'Bathroom', 'Car','Propertycount']].fillna(0)

# %%
data
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# ...

# %%
# Fill missing values
data['Landsize'] = data['Landsize'].fillna(data.Landsize.mean())
data['BuildingArea'] = data['BuildingArea'].fillna(data.BuildingArea.mean())

# %%
data
# Out:
#            Suburb  Rooms Type      Price Method        SellerG  Distance  \
# 0      Abbotsford      2    h        NaN     SS         Jellis       2.5
# 1      Abbotsford      2    h  1480000.0      S         Biggin       2.5
# 2      Abbotsford      2    h  1035000.0      S         Biggin       2.5
# 3      Abbotsford      3    u        NaN     VB         Rounds       2.5
# 4      Abbotsford      3    h  1465000.0     SP         Biggin       2.5
# ...           ...    ...  ...        ...    ...            ...       ...
# 34852  Yarraville      4    h  1480000.0     PI            Jas       6.3
# 34853  Yarraville      2    h   888000.0     SP        Sweeney       6.3
# 34854  Yarraville      2    t   705000.0      S            Jas       6.3
# 34855  Yarraville      3    h  1140000.0     SP  hockingstuart       6.3
# 34856  Yarraville      2    h  1020000.0     PI             RW       6.3
#
#        Bedroom2  Bathroom  Car    Landsize  BuildingArea  \
# ...

# %%
# Drop null values 
data.dropna(inplace = True)

# %%
# Recheck the null values 
data.isnull().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Distance         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# CouncilArea      0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
# check the shape of the data so it get changea as per our need 
data.shape
# Out:
# (27244, 15)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# Exploratory Data Analysis is performed to understand the relationships between different variables and identify patterns in the data.
#
# This includes:
# - Analyzing distribution of house prices
# - Studying relationship between area and price
# - Identifying key features influencing house prices
#
# EDA helps in gaining insights and guiding feature selection for model building.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27244 entries, 1 to 34856
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         27244 non-null  object
#  1   Rooms          27244 non-null  int64
#  2   Type           27244 non-null  object
#  3   Price          27244 non-null  float64
#  4   Method         27244 non-null  object
#  5   SellerG        27244 non-null  object
#  6   Distance       27244 non-null  float64
#  7   Bedroom2       27244 non-null  float64
#  8   Bathroom       27244 non-null  float64
#  9   Car            27244 non-null  float64
#  10  Landsize       27244 non-null  float64
#  11  BuildingArea   27244 non-null  float64
#  12  CouncilArea    27244 non-null  object
#  13  Regionname     27244 non-null  object
#  14  Propertycount  27244 non-null  float64
# dtypes: float64(8), int64(1), object(6)
# memory usage: 3.3+ MB

# %%
data['Method'].unique()
# Out:
# array(['S', 'SP', 'PI', 'VB', 'SA'], dtype=object)

# %%
data['SellerG'].unique()
# Out:
# array(['Biggin', 'Nelson', 'Jellis', 'Dingle', 'Purplebricks', 'Greg',
#        'LITTLE', 'Collins', 'Kay', 'Beller', 'Marshall', 'hockingstuart',
#        'Brad', 'Maddison', 'Barry', 'Airport', 'Considine', 'Rendina',
#        'Ray', 'Propertyau', 'McDonald', 'Frank', 'Prof.', 'Harcourts',
#        'Thomson', 'Buxton', 'RT', "Sotheby's", 'Cayzer', 'Chisholm',
#        'Brace', 'Miles', 'Holland', 'McGrath', 'Love', 'Thomas', 'Barlow',
#        'Sweeney', 'Village', 'Jas', 'Williams', 'Gunn&Co', 'Burnham',
#        'Compton', 'FN', 'Hunter', 'Raine&Horne', 'Noel', 'Hodges', 'Gary',
#        'Fletchers', 'Woodards', 'Raine', 'Alexkarbon', 'Walshe', 'Weda',
#        'Stockdale', 'Tim', 'AIME', 'Moonee', 'HAR', 'Edward', 'Philip',
#        'RW', 'North', 'MICM', 'Ascend', 'Christopher', 'Morrison',
#        'Mandy', 'R&H', 'Fletchers/One', 'Lindellas', 'Appleby', 'Assisi',
#        'One', 'Owen', 'Parkes', 'C21', "O'Brien", 'Bayside', 'Paul',
# ...

# %%
data['CouncilArea'].unique()
# Out:
# array(['Yarra City Council', 'Moonee Valley City Council',
#        'Port Phillip City Council', 'Darebin City Council',
#        'Hobsons Bay City Council', 'Stonnington City Council',
#        'Boroondara City Council', 'Monash City Council',
#        'Glen Eira City Council', 'Whitehorse City Council',
#        'Maribyrnong City Council', 'Bayside City Council',
#        'Moreland City Council', 'Manningham City Council',
#        'Melbourne City Council', 'Banyule City Council',
#        'Brimbank City Council', 'Kingston City Council',
#        'Hume City Council', 'Knox City Council', 'Maroondah City Council',
#        'Casey City Council', 'Melton City Council',
#        'Greater Dandenong City Council', 'Nillumbik Shire Council',
#        'Whittlesea City Council', 'Frankston City Council',
#        'Macedon Ranges Shire Council', 'Yarra Ranges Shire Council',
#        'Wyndham City Council', 'Cardinia Shire Council',
# ...

# %%
data['Regionname'].unique()
# Out:
# array(['Northern Metropolitan', 'Western Metropolitan',
#        'Southern Metropolitan', 'Eastern Metropolitan',
#        'South-Eastern Metropolitan', 'Eastern Victoria',
#        'Northern Victoria', 'Western Victoria'], dtype=object)

# %% [markdown]
# ## Feature Engineering
#
# Feature engineering involves transforming raw data into meaningful features that improve model performance.
#
# In this step:
# - Categorical variables are converted into numerical format
# - Irrelevant features are removed
# - Important features are selected for modeling
#
# This step ensures that the data is suitable for machine learning algorithms.

# %%
# Convert categorical variables into numerical
data = pd.get_dummies(data, drop_first = True)

# %%
data.shape
# Out:
# (27244, 745)

# %%
data.head()
# Out:
#    Rooms      Price  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 1      2  1480000.0       2.5       2.0       1.0  1.0     202.0
# 2      2  1035000.0       2.5       2.0       1.0  0.0     156.0
# 4      3  1465000.0       2.5       3.0       2.0  0.0     134.0
# 5      3   850000.0       2.5       3.0       2.0  1.0      94.0
# 6      4  1600000.0       2.5       3.0       1.0  2.0     120.0
#
#    BuildingArea  Propertycount  Suburb_Aberfeldie  ...  \
# 1      160.2564         4019.0              False  ...
# 2       79.0000         4019.0              False  ...
# 4      150.0000         4019.0              False  ...
# 5      160.2564         4019.0              False  ...
# 6      142.0000         4019.0              False  ...
#
#    CouncilArea_Wyndham City Council  CouncilArea_Yarra City Council  \
# 1                             False                            True
# 2                             False                            True
# ...

# %% [markdown]
# ## Model Building
#
# In this step, a machine learning model is built to predict house prices.
#
# Linear Regression is used as the baseline model due to its simplicity and effectiveness for regression problems.
#
# The dataset is split into training and testing sets to evaluate model performance on unseen data.

# %%
# Define features and target
x = data.drop('Price', axis = 1)
y = data['Price']

# %%
x.head()
# Out:
#    Rooms  Distance  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 1      2       2.5       2.0       1.0  1.0     202.0      160.2564
# 2      2       2.5       2.0       1.0  0.0     156.0       79.0000
# 4      3       2.5       3.0       2.0  0.0     134.0      150.0000
# 5      3       2.5       3.0       2.0  1.0      94.0      160.2564
# 6      4       2.5       3.0       1.0  2.0     120.0      142.0000
#
#    Propertycount  Suburb_Aberfeldie  Suburb_Airport West  ...  \
# 1         4019.0              False                False  ...
# 2         4019.0              False                False  ...
# 4         4019.0              False                False  ...
# 5         4019.0              False                False  ...
# 6         4019.0              False                False  ...
#
#    CouncilArea_Wyndham City Council  CouncilArea_Yarra City Council  \
# 1                             False                            True
# ...

# %%
x.shape
# Out:
# (27244, 744)

# %%
# Split dataset
from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test = train_test_split(x,y,test_size = 0.3, random_state = 2)

# %%
x_train.shape
# Out:
# (19070, 744)

# %%
x_test.shape
# Out:
# (8174, 744)

# %%
# Train model
from sklearn.linear_model import LinearRegression 
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Model Evaluation
#
# The model is evaluated using standard regression metrics:
#
# - R² Score: Measures how well the model explains the variance in the data
# - Mean Absolute Error (MAE): Measures the average prediction error
#
# These metrics help in understanding the accuracy and reliability of the model.

# %%
# Predictions
y_predict = model.predict(x_test)
y_predict
# Out:
# array([1672988.74423118, 1086049.72133639,  852828.79000837, ...,
#         891754.56465992,  783898.88694562, 1170611.74698261],
#       shape=(8174,))

# %%
## Evaluation metrics
model.intercept_
# Out:
# np.float64(636394.7291090852)

# %%
model.coef_
# Out:
# array([ 2.64001655e+05, -4.64732744e+04, -8.22349031e+04,  1.17151153e+05,
#         4.29703140e+04,  2.35173742e+00,  4.70024530e+02,  4.92118905e+00,
#         2.61342069e+05, -4.61008827e+04, -1.32312259e+05,  2.15453995e+05,
#         1.20133839e+05,  2.72683980e+05,  1.74702166e+05, -8.00201053e+04,
#        -1.50967673e+05, -4.94461444e+04,  1.17711126e+05, -1.28880253e+05,
#        -3.49349656e+04, -8.54261329e+03,  6.19157896e+04, -2.57258028e+05,
#        -1.10868116e+05, -2.42391674e+05,  1.79856957e+05, -1.22395100e+05,
#         2.04625284e+05,  3.78258911e+04,  1.46681364e+05,  2.32198630e+03,
#         7.35395731e+04, -5.29198410e+04,  1.90482393e+05, -3.20451670e+05,
#         7.49515014e+04, -2.83019804e+04,  2.69103300e+04,  2.78824270e+05,
#         1.51386730e+05, -1.06324212e+05, -8.45087700e+04,  2.96568248e+05,
#         1.50644588e+05, -7.60424882e-07,  1.75999576e+05, -1.20057166e+05,
# ...

# %%
#training accuracy
model.score(x_train, y_train)*100
# Out:
# 68.27792395792723

# %%
#testing Accuracy
model.score(x_test,y_test)*100
# Out:
# 13.853683161586815

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
ridge_reg= Ridge(alpha=50, max_iter=100,)
ridge_reg.fit(x_train, y_train)
# Out:
# Ridge(alpha=50, max_iter=100)

# %%
ridge_reg.score(x_train, y_train)*100
# Out:
# 66.22376739684329

# %%
ridge_reg.score(x_test, y_test)*100
# Out:
# 66.70848945194956

# %%
from sklearn.metrics import mean_squared_error,r2_score, mean_absolute_error

# %%
y_predicted = ridge_reg.predict(x_test)
y_predicted
# Out:
# array([1627362.97274832, 1040671.45389949,  905510.14874907, ...,
#         931940.4305978 ,  800466.36204517, 1241927.30653571],
#       shape=(8174,))

# %%
r2_score(y_test,y_predicted)*100
# Out:
# 66.70848945194956

# %%
mean_squared_error(y_test,y_predicted)
# Out:
# 132273414674.95786

# %%
mean_absolute_error(y_test,y_predicted)
# Out:
# 236797.37116612244

# %% [markdown]
# ## Lasso Regression

# %%
from sklearn.linear_model import Lasso

# %%
lasso_reg = Lasso(alpha=50, max_iter=100)
lasso_reg.fit(x_train, y_train)
# Out:
# C:\Users\ritus\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.329e+15, tolerance: 7.963e+11
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=50, max_iter=100)

# %%
lasso_reg.score(x_train, y_train)
# Out:
# 0.6767356948457683

# %%
lasso_reg.score(x_test,y_test)
# Out:
# 0.6637669697137103

# %%
## 🚀Conclusion

The project successfully demonstrates how machine learning can be used to predict house prices based on property features.

Key takeaways:
- Area and location are major factors influencing price  
- Data cleaning and feature engineering significantly improve model performance  
- The model provides reasonably accurate predictions  

Future improvements:
- Use advanced models like Random Forest or XGBoost  
- Include more features for better accuracy
